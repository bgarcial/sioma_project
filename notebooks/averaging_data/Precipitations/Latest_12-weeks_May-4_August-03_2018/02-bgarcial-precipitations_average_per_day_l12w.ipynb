# %%
from __future__ import unicode_literals

import pandas as pd
import numpy as np

# %%
precipitations_l12w_df = pd.read_csv('../../../../data/raw/FincaPorvenir/Metereologico/Latest_12-weeks_May-4_August-03_2018/' \
                                 'Precipitacion_May-4_August-03_2018.csv', )

# %%
print(precipitations_l12w_df.shape)
precipitations_l12w_df.head()
# Out:
# (4397, 2)
#                 Fecha:  Precipitación (ml)
# 0  2018-05-04 00:07:38                 0.0
# 1  2018-05-04 00:37:39                 0.0
# 2  2018-05-04 01:07:38                 0.0
# 3  2018-05-04 01:37:38                 0.0
# 4  2018-05-04 02:07:38                 0.0

# %% [markdown]
# - We going to generate in only one dataframe one record per day of precipitations values, performing an average of the values per day.

# %%
# We turn to datetime the Fecha column values 
# https://pandas.pydata.org/pandas-docs/version/0.20/generated/pandas.to_datetime.html
precipitations_l12w_df['Fecha:'] = pd.to_datetime(precipitations_l12w_df['Fecha:'])

# http://pandas.pydata.org/pandas-docs/stable/generated/pandas.DataFrame.resample.html
# We use resample() function to use the data like time series per day and we pass the
# Fecha: column at the on parameter and we add the Precipitación (ml) column which we add the 
# average of each one

precipitations_l12w_average_per_day = precipitations_l12w_df.resample('D', on='Fecha:')['Precipitación (ml)'].mean().reset_index()

# %%
print(precipitations_l12w_average_per_day.shape)
precipitations_l12w_average_per_day
# Out:
# (92, 2)
#        Fecha:  Precipitación (ml)
# 0  2018-05-04            0.000000
# 1  2018-05-05            0.259792
# 2  2018-05-06            0.048333
# 3  2018-05-07            1.116458
# 4  2018-05-08            0.024167
# 5  2018-05-09            0.166596
# 6  2018-05-10            0.327708
# 7  2018-05-11            0.030208
# 8  2018-05-12            0.030208
# 9  2018-05-13            0.000000
# 10 2018-05-14            0.114792
# 11 2018-05-15            0.000000
# 12 2018-05-16            0.024167
# 13 2018-05-17            0.000000
# 14 2018-05-18            0.326250
# 15 2018-05-19            0.205417
# 16 2018-05-20            0.000000
# 17 2018-05-21            0.078542
# 18 2018-05-22            0.146122
# 19 2018-05-23            0.316531
# 20 2018-05-24            0.000000
# 21 2018-05-25            0.000000
# 22 2018-05-26            0.036250
# 23 2018-05-27            0.163265
# 24 2018-05-28            0.000000
# 25 2018-05-29            0.000000
# ...

# %%
# We export the precipitations_l12w_average_per_day dataframe to .csv file
precipitations_l12w_average_per_day.to_csv('../../../../data/interim/Precipitations/Latest_12-weeks_May-4_August-03_2018/' +'\n' 
                                  'Precipitations_Average_per-day_May-4_August-03.csv', sep=',', header=True, index=False)
